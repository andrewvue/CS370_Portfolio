# %%
from __future__ import print_function

import numpy as np

from keras.datasets import mnist

from keras.models import Sequential

from keras.layers.core import Dense, Activation

from keras.optimizers import SGD

from keras.utils import np_utils

np.random.seed(1671) # for reproducibility

# network and training

NB_EPOCH = 20

BATCH_SIZE = 128

VERBOSE = 1

NB_CLASSES = 10 # number of outputs = number of digits

OPTIMIZER = SGD() # optimizer, explained later in this chapter

N_HIDDEN = 128

VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION

# data: shuffled and split between train and test sets

(X_train, y_train), (X_test, y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784

RESHAPED = 784

#

X_train = X_train.reshape(60000, RESHAPED)

X_test = X_test.reshape(10000, RESHAPED)

X_train = X_train.astype('float32')

X_test = X_test.astype('float32')

# normalize

X_train /= 255

X_test /= 255

print(X_train.shape[0], 'train samples')

print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices

Y_train = np_utils.to_categorical(y_train, NB_CLASSES)

Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# M_HIDDEN hidden layers

# 10 outputs

# final stage is softmax

model = Sequential()

model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))

model.add(Activation('relu'))

model.add(Dense(N_HIDDEN))

model.add(Activation('relu'))

model.add(Dense(NB_CLASSES))

model.add(Activation('softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',

optimizer=OPTIMIZER,

metrics=['accuracy'])

history1 = model.fit(X_train, Y_train,

batch_size=BATCH_SIZE, epochs=NB_EPOCH,

verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

score = model.evaluate(X_test, Y_test, verbose=VERBOSE)

print("Test score:", score[0])

print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 128)               100480
# _________________________________________________________________
# activation_13 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_14 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                1290
# _________________________________________________________________
# activation_15 (Activation)   (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 5s 96us/step - loss: 1.4214 - accuracy: 0.6623 - val_loss: 0.7142 - val_accuracy: 0.8489
# Epoch 2/20
# 48000/48000 [==============================] - 5s 106us/step - loss: 0.5760 - accuracy: 0.8573 - val_loss: 0.4416 - val_accuracy: 0.8837
# Epoch 3/20
# 48000/48000 [==============================] - 4s 87us/step - loss: 0.4325 - accuracy: 0.8821 - val_loss: 0.3700 - val_accuracy: 0.8978
# Epoch 4/20
# 48000/48000 [==============================] - 4s 92us/step - loss: 0.3779 - accuracy: 0.8950 - val_loss: 0.3350 - val_accuracy: 0.9038
# Epoch 5/20
# 48000/48000 [==============================] - 4s 84us/step - loss: 0.3462 - accuracy: 0.9025 - val_loss: 0.3116 - val_accuracy: 0.9101
# Epoch 6/20
# 48000/48000 [==============================] - 4s 86us/step - loss: 0.3236 - accuracy: 0.9083 - val_loss: 0.2944 - val_accuracy: 0.9151
# Epoch 7/20
# 48000/48000 [==============================] - 4s 83us/step - loss: 0.3057 - accuracy: 0.9134 - val_loss: 0.2794 - val_accuracy: 0.9208
# Epoch 8/20
# 48000/48000 [==============================] - 4s 91us/step - loss: 0.2907 - accuracy: 0.9172 - val_loss: 0.2669 - val_accuracy: 0.9229
# Epoch 9/20
# 48000/48000 [==============================] - 4s 88us/step - loss: 0.2783 - accuracy: 0.9206 - val_loss: 0.2571 - val_accuracy: 0.9268
# Epoch 10/20
# 48000/48000 [==============================] - 4s 87us/step - loss: 0.2670 - accuracy: 0.9241 - val_loss: 0.2486 - val_accuracy: 0.9282
# Epoch 11/20
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.2568 - accuracy: 0.9271 - val_loss: 0.2395 - val_accuracy: 0.9312
# Epoch 12/20
# 48000/48000 [==============================] - 4s 83us/step - loss: 0.2473 - accuracy: 0.9294 - val_loss: 0.2323 - val_accuracy: 0.9346
# Epoch 13/20
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.2387 - accuracy: 0.9324 - val_loss: 0.2274 - val_accuracy: 0.9344
# Epoch 14/20
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.2310 - accuracy: 0.9342 - val_loss: 0.2196 - val_accuracy: 0.9375
# Epoch 15/20
# 48000/48000 [==============================] - 4s 88us/step - loss: 0.2234 - accuracy: 0.9367 - val_loss: 0.2127 - val_accuracy: 0.9396
# Epoch 16/20
# 48000/48000 [==============================] - 4s 83us/step - loss: 0.2166 - accuracy: 0.9389 - val_loss: 0.2069 - val_accuracy: 0.9433
# Epoch 17/20
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.2101 - accuracy: 0.9403 - val_loss: 0.2017 - val_accuracy: 0.9452
# Epoch 18/20
# 48000/48000 [==============================] - 5s 111us/step - loss: 0.2040 - accuracy: 0.9418 - val_loss: 0.1971 - val_accuracy: 0.9452
# Epoch 19/20
# 48000/48000 [==============================] - 4s 83us/step - loss: 0.1982 - accuracy: 0.9434 - val_loss: 0.1929 - val_accuracy: 0.9475
# Epoch 20/20
# 48000/48000 [==============================] - 4s 83us/step - loss: 0.1929 - accuracy: 0.9452 - val_loss: 0.1882 - val_accuracy: 0.9487
# 10000/10000 [==============================] - 0s 43us/step
# Test score: 0.19098283562883736
# Test accuracy: 0.9452999830245972

# %%
from __future__ import print_function

import numpy as np

from keras.datasets import mnist

from keras.models import Sequential

from keras.layers.core import Dense, Activation

from keras.optimizers import SGD

from keras.utils import np_utils

np.random.seed(1671) # for reproducibility

# network and training

NB_EPOCH = 10

BATCH_SIZE = 32

VERBOSE = 1

NB_CLASSES = 10 # number of outputs = number of digits

OPTIMIZER = SGD() # optimizer, explained later in this chapter

N_HIDDEN = 128

VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION

# data: shuffled and split between train and test sets

(X_train, y_train), (X_test, y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784

RESHAPED = 784

#

X_train = X_train.reshape(60000, RESHAPED)

X_test = X_test.reshape(10000, RESHAPED)

X_train = X_train.astype('float32')

X_test = X_test.astype('float32')

# normalize

X_train /= 255

X_test /= 255

print(X_train.shape[0], 'train samples')

print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices

Y_train = np_utils.to_categorical(y_train, NB_CLASSES)

Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# M_HIDDEN hidden layers

# 10 outputs

# final stage is softmax

model2 = Sequential()

model2.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))

model2.add(Activation('relu'))

model2.add(Dense(N_HIDDEN))

model2.add(Activation('relu'))

model2.add(Dense(NB_CLASSES))

model2.add(Activation('softmax'))

model2.summary()

model2.compile(loss='categorical_crossentropy',

optimizer=OPTIMIZER,

metrics=['accuracy'])

history2= model2.fit(X_train, Y_train,

batch_size=BATCH_SIZE, epochs=NB_EPOCH,

verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

score = model2.evaluate(X_test, Y_test, verbose=VERBOSE)

print("Test score:", score[0])

print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               100480
# _________________________________________________________________
# activation_4 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_5 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 12s 244us/step - loss: 0.7324 - accuracy: 0.8045 - val_loss: 0.3332 - val_accuracy: 0.9084
# Epoch 2/10
# 48000/48000 [==============================] - 13s 269us/step - loss: 0.3158 - accuracy: 0.9097 - val_loss: 0.2656 - val_accuracy: 0.9241
# Epoch 3/10
# 48000/48000 [==============================] - 12s 260us/step - loss: 0.2603 - accuracy: 0.9270 - val_loss: 0.2303 - val_accuracy: 0.9348
# Epoch 4/10
# 48000/48000 [==============================] - 13s 261us/step - loss: 0.2243 - accuracy: 0.9371 - val_loss: 0.2018 - val_accuracy: 0.9423
# Epoch 5/10
# 48000/48000 [==============================] - 11s 230us/step - loss: 0.1975 - accuracy: 0.9439 - val_loss: 0.1848 - val_accuracy: 0.9483
# Epoch 6/10
# 48000/48000 [==============================] - 12s 247us/step - loss: 0.1771 - accuracy: 0.9499 - val_loss: 0.1715 - val_accuracy: 0.9512
# Epoch 7/10
# 48000/48000 [==============================] - 14s 291us/step - loss: 0.1601 - accuracy: 0.9542 - val_loss: 0.1590 - val_accuracy: 0.9547
# Epoch 8/10
# 48000/48000 [==============================] - 17s 363us/step - loss: 0.1458 - accuracy: 0.9581 - val_loss: 0.1507 - val_accuracy: 0.9585
# Epoch 9/10
# 48000/48000 [==============================] - 17s 348us/step - loss: 0.1343 - accuracy: 0.9612 - val_loss: 0.1381 - val_accuracy: 0.9621
# Epoch 10/10
# 48000/48000 [==============================] - 18s 369us/step - loss: 0.1237 - accuracy: 0.9646 - val_loss: 0.1344 - val_accuracy: 0.9624
# 10000/10000 [==============================] - 0s 30us/step
# Test score: 0.13176407354436814
# Test accuracy: 0.9606999754905701

# %%
from __future__ import print_function

import numpy as np

from keras.datasets import mnist

from keras.models import Sequential

from keras.layers.core import Dense, Activation

from keras.optimizers import SGD

from keras.utils import np_utils

np.random.seed(1671) # for reproducibility

# network and training

NB_EPOCH = 10

BATCH_SIZE = 32

VERBOSE = 1

NB_CLASSES = 10 # number of outputs = number of digits

OPTIMIZER = SGD() # optimizer, explained later in this chapter

N_HIDDEN = 128

VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION

# data: shuffled and split between train and test sets

(X_train, y_train), (X_test, y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784

RESHAPED = 784

#

X_train = X_train.reshape(60000, RESHAPED)

X_test = X_test.reshape(10000, RESHAPED)

X_train = X_train.astype('float32')

X_test = X_test.astype('float32')

# normalize

X_train /= 255

X_test /= 255

print(X_train.shape[0], 'train samples')

print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices

Y_train = np_utils.to_categorical(y_train, NB_CLASSES)

Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# M_HIDDEN hidden layers

# 10 outputs

# final stage is softmax

model2 = Sequential()

model2.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))

model2.add(Activation('relu'))

model2.add(Dense(N_HIDDEN))

model2.add(Activation('relu'))

model2.add(Dense(NB_CLASSES))

model2.add(Activation('softmax'))

model2.summary()

model2.compile(loss='categorical_crossentropy',

optimizer=OPTIMIZER,

metrics=['accuracy'])

history2= model2.fit(X_train, Y_train,

batch_size=BATCH_SIZE, epochs=NB_EPOCH,

verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

score = model2.evaluate(X_test, Y_test, verbose=VERBOSE)

print("Test score:", score[0])

print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 128)               100480
# _________________________________________________________________
# activation_7 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_8 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation_9 (Activation)    (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 12s 251us/step - loss: 0.7506 - accuracy: 0.8050 - val_loss: 0.3446 - val_accuracy: 0.9053
# Epoch 2/10
# 48000/48000 [==============================] - 15s 321us/step - loss: 0.3225 - accuracy: 0.9087 - val_loss: 0.2754 - val_accuracy: 0.9218
# Epoch 3/10
# 48000/48000 [==============================] - 15s 318us/step - loss: 0.2667 - accuracy: 0.9232 - val_loss: 0.2388 - val_accuracy: 0.9317
# Epoch 4/10
# 48000/48000 [==============================] - 14s 294us/step - loss: 0.2328 - accuracy: 0.9338 - val_loss: 0.2128 - val_accuracy: 0.9390
# Epoch 5/10
# 48000/48000 [==============================] - 12s 256us/step - loss: 0.2071 - accuracy: 0.9405 - val_loss: 0.1955 - val_accuracy: 0.9454
# Epoch 6/10
# 48000/48000 [==============================] - 16s 344us/step - loss: 0.1873 - accuracy: 0.9463 - val_loss: 0.1811 - val_accuracy: 0.9478
# Epoch 7/10
# 48000/48000 [==============================] - 16s 332us/step - loss: 0.1699 - accuracy: 0.9508 - val_loss: 0.1691 - val_accuracy: 0.9538
# Epoch 8/10
# 48000/48000 [==============================] - 20s 425us/step - loss: 0.1554 - accuracy: 0.9556 - val_loss: 0.1590 - val_accuracy: 0.9562
# Epoch 9/10
# 48000/48000 [==============================] - 16s 331us/step - loss: 0.1433 - accuracy: 0.9581 - val_loss: 0.1466 - val_accuracy: 0.9583
# Epoch 10/10
# 48000/48000 [==============================] - 15s 317us/step - loss: 0.1327 - accuracy: 0.9618 - val_loss: 0.1417 - val_accuracy: 0.9600
# 10000/10000 [==============================] - 0s 28us/step
# Test score: 0.1403740623407066
# Test accuracy: 0.9589999914169312

# %%
from __future__ import print_function

import numpy as np

from keras.datasets import mnist

from keras.models import Sequential

from keras.layers.core import Dense, Activation

from keras.optimizers import SGD

from keras.utils import np_utils

np.random.seed(1671) # for reproducibility

# network and training

NB_EPOCH = 20

BATCH_SIZE = 256

VERBOSE = 0

NB_CLASSES = 10 # number of outputs = number of digits

OPTIMIZER = SGD() # optimizer, explained later in this chapter

N_HIDDEN = 128

VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION

# data: shuffled and split between train and test sets

(X_train, y_train), (X_test, y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784

RESHAPED = 784

#

X_train = X_train.reshape(60000, RESHAPED)

X_test = X_test.reshape(10000, RESHAPED)

X_train = X_train.astype('float32')

X_test = X_test.astype('float32')

# normalize

X_train /= 255

X_test /= 255

print(X_train.shape[0], 'train samples')

print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices

Y_train = np_utils.to_categorical(y_train, NB_CLASSES)

Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# M_HIDDEN hidden layers

# 10 outputs

# final stage is softmax

model3 = Sequential()

model3.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))

model3.add(Activation('relu'))

model3.add(Dense(N_HIDDEN))
model3.add(Activation('relu'))

model3.add(Dense(NB_CLASSES))

model3.add(Activation('softmax'))

model3.summary()

model3.compile(loss='categorical_crossentropy',

optimizer=OPTIMIZER,

metrics=['accuracy'])

history3= model3.fit(X_train, Y_train,

batch_size=BATCH_SIZE, epochs=NB_EPOCH,

verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

score = model3.evaluate(X_test, Y_test, verbose=VERBOSE)

print("Test score:", score[0])

print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 128)               100480
# _________________________________________________________________
# activation_10 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_11 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                1290
# _________________________________________________________________
# activation_12 (Activation)   (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Test score: 0.25533106629550456
# Test accuracy: 0.9261999726295471

# %%
import matplotlib.pyplot as plt
def plot_graphs(hist_list, string):
  fig=plt.figure(figsize=(10,10))  
  for i in range(len(hist_list)):
        
       ax=fig.add_subplot(3,2,i+1)

       ax.plot(hist_list[i].history[string])
       ax.plot(hist_list[i].history['val_'+string])
       ax.set_xlabel("Epochs")
       ax.set_ylabel(string)
       ax.legend([string, 'val_'+string])
       ax.set_title("history_"+str(i+1))

plot_graphs([history1,history2,history3], 'accuracy')
plot_graphs([history1,history2,history3], 'loss')
